# %% [markdown]
# ### Purpose
# Stitch images in a folder utilizing a prepared CSV that corresponds an image filename to a right-down image index for feeding the set of images into Fiji/ImageJ right-down grid stitching.

# %%
#if the renaming CSV is not in the same dir as the images to be renamed and stitched, go to CSV directory

# %cd /Users/sydneyzink/Desktop/
# Out:
# /Users/sydneyzink/Desktop

# %%
import pandas as pd
import os

# %%
#create a pandas dataframe from a csv that should have image filenames in one column,
#corresponding image index for stitching in the other column

worksheet = pd.read_csv("vertical_img_mapping.csv", header=None, index_col=0)
worksheet.head()
# Out:
#             1
# 0
# A01f00  img21
# A01f01  img27
# A01f02  img33
# A01f03  img39
# A01f04  img45

# %%
stitch_idxs_dict = worksheet.to_dict()[1]
stitch_idxs_dict
# Out:
# {'A01f00': 'img21',
#  'A01f01': 'img27',
#  'A01f02': 'img33',
#  'A01f03': 'img39',
#  'A01f04': 'img45',
#  'A01f05': 'img51',
#  'A01f06': 'img57',
#  'A01f07': 'img58',
#  'A01f08': 'img52',
#  'A01f09': 'img46',
#  'A01f10': 'img40',
#  'A01f11': 'img34',
#  'A01f12': 'img28',
#  'A01f13': 'img22',
#  'A01f14': 'img16',
#  'A01f15': 'img15',
#  'A01f16': 'img14',
#  'A01f17': 'img20',
#  'A01f18': 'img26',
#  'A01f19': 'img32',
#  'A01f20': 'img38',
#  'A01f21': 'img44',
#  'A01f22': 'img50',
#  'A01f23': 'img56',
#  'A01f24': 'img62',
#  'A01f25': 'img63',
#  'A01f26': 'img64',
#  'A01f27': 'img65',
#  'A01f28': 'img59',
#  'A01f29': 'img53',
#  'A01f30': 'img47',
#  'A01f31': 'img41',
#  'A01f32': 'img35',
#  'A01f33': 'img29',
#  'A01f34': 'img23',
#  'A01f35': 'img17',
#  'A01f36': 'img11',
#  'A01f37': 'img10',
#  'A01f38': 'img9',
#  'A01f39': 'img8',
#  'A01f40': 'img7',
#  'A01f41': 'img13',
#  'A01f42': 'img19',
#  'A01f43': 'img25',
#  'A01f44': 'img31',
#  'A01f45': 'img37',
#  'A01f46': 'img43',
#  'A01f47': 'img49',
#  'A01f48': 'img55',
#  'A01f49': 'img61',
#  'A01f50': 'img67',
#  'A01f51': 'img68',
#  'A01f52': 'img69',
#  'A01f53': 'img70',
#  'A01f54': 'img71',
#  'A01f55': 'img72',
#  'A01f56': 'img66',
#  'A01f57': 'img60',
#  'A01f58': 'img54',
#  'A01f59': 'img48',
#  'A01f60': 'img42',
#  'A01f61': 'img36',
#  'A01f62': 'img30',
#  'A01f63': 'img24',
#  'A01f64': 'img18',
#  'A01f65': 'img12',
#  'A01f66': 'img6',
#  'A01f67': 'img5',
#  'A01f68': 'img4',
#  'A01f69': 'img3',
#  'A01f70': 'img2',
#  'A01f71': 'img1'}

# %%
#if the renaming CSV is not in the same dir as the images to be renamed and stitched, go now to imgs directory

# %cd /Users/sydneyzink/Desktop/old_Vertical_JPG/
# Out:
# /Users/sydneyzink/Desktop/old_Vertical_JPG

# %%
#ensure there are no duplicate indices
#should not print anything if no duplicate indices

vals = []
for k, v in stitch_idxs_dict.items():
    if v in vals:
        print(v)
    else:
        vals.append(v)

# %%
#ensure every value in the size of the imgs set has its index among the new img names
#should not print anything if no missing indices in range

for i in range(1, len(stitch_idxs_dict)):
    if i not in idxs_set:
        print(i)

# %%
#rename the images for right-down Fiji/ImageJ grid stitching
#ensure final count of renames matches with length of renaming dictionary

count = 0

for filename in os.listdir('.'):
    filen = filename.split('_')[-1].split('.')[0]
    
    if "A01" not in filen: #don't use protocol file or some other non-image
        continue
    if filen[-2:] != "d0": #don't use d4, those are all black
        continue
    
    filen = filen[:-2] #cut off the d4/d0 to match dict keys
    val = stitch_idxs_dict[filen]
    if len(val) == 4: #single-digit image index
        val_sections = val.split("g")
        val = val_sections[0] + "g" + "0" + val_sections[1]
    val = val + ".jpg"
    
    print(val)
    print(filename)
    
    os.rename(filename, val)
    count += 1

print(count)
# Out:
# img31.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f44d0.jpg
# img27.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f01d0.jpg
# img42.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f60d0.jpg
# img63.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f25d0.jpg
# img26.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f18d0.jpg
# img30.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f62d0.jpg
# img65.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f27d0.jpg
# img43.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f46d0.jpg
# img39.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f03d0.jpg
# img19.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f42d0.jpg
# img58.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f07d0.jpg
# img06.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f66d0.jpg
# img56.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f23d0.jpg
# img18.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f64d0.jpg
# img44.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f21d0.jpg
# img48.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f59d0.jpg
# img09.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f38d0.jpg
# img07.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f40d0.jpg
# img51.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f05d0.jpg
# img64.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f26d0.jpg
# img24.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f63d0.jpg
# img33.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f02d0.jpg
# img49.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f47d0.jpg
# img21.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f00d0.jpg
# img37.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f45d0.jpg
# img32.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f19d0.jpg
# img62.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f24d0.jpg
# img36.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f61d0.jpg
# img54.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f58d0.jpg
# img38.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f20d0.jpg
# img12.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f65d0.jpg
# img45.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f04d0.jpg
# img13.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f41d0.jpg
# img08.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f39d0.jpg
# img57.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f06d0.jpg
# img25.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f43d0.jpg
# img50.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f22d0.jpg
# img05.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f67d0.jpg
# img66.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f56d0.jpg
# img22.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f13d0.jpg
# img10.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f37d0.jpg
# img02.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f70d0.jpg
# img17.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f35d0.jpg
# img52.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f08d0.jpg
# img03.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f69d0.jpg
# img71.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f54d0.jpg
# img34.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f11d0.jpg
# img59.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f28d0.jpg
# img67.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f50d0.jpg
# img15.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f15d0.jpg
# img41.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f31d0.jpg
# img61.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f49d0.jpg
# img29.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f33d0.jpg
# img69.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f52d0.jpg
# img20.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f17d0.jpg
# img46.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f09d0.jpg
# img23.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f34d0.jpg
# img01.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f71d0.jpg
# img40.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f10d0.jpg
# img72.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f55d0.jpg
# img04.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f68d0.jpg
# img28.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f12d0.jpg
# img60.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f57d0.jpg
# img11.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f36d0.jpg
# img35.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f32d0.jpg
# img14.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f16d0.jpg
# img70.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f53d0.jpg
# img16.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f14d0.jpg
# img68.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f51d0.jpg
# img53.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f29d0.jpg
# img55.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f48d0.jpg
# img47.jpg
# 12-2-CHIP2_Bottom Slide_M_p00_0_A01f30d0.jpg
# 72
